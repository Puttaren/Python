# %%
from openpyxl import Workbook
import os
os.chdir("d:/Downloads")
workbook = Workbook()
sheet = workbook.active
sheet.title = "Data"

data = [
    ["Namn", "Ålder", "Stad"],
    ["Alice", 30, "Stockholm"],
    ["Bob", 25, "Göteborg"],
    ["Charlie", 35, "Malmö"],
]

for row in data:
    sheet.append(row)

workbook.save("data.xlsx")
